# %% [markdown]
# # Тематическое моделирование

# %%
import numpy as np
import pandas as pd
import ast
import nltk
from nltk.corpus import stopwords
import gensim
import gensim.corpora as corpora
from gensim import models
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.models import TfidfModel
import spacy
import pyLDAvis
import pyLDAvis.gensim
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/NLP/Handin/Data/df_tokenized.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                               tokens sentiment
# 0  ['everyth', 'perfect', 'nice', 'clean', 'every...  positive
# 1  ['appart', 'beautiful', 'veri', 'friendli', 'h...  positive
# 2  ['spent', 'excel', 'night', 'thi', 'apart', 'g...  positive
# 3  ['great', 'host', 'super', 'respons', 'make', ...  positive
# 4  ['properti', 'great', 'locat', 'base', 'look',...  positive

# %% [markdown]
# В следующих шагах оставляем только существительные, прилагательные, глаголы и наречия

# %%
data = df['tokens'].apply(ast.literal_eval)
data = data.tolist()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
nlp = spacy.load('en_core_web_sm')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
final_data = []
for tokens in tqdm(data):
    review = nlp(' '.join(tokens))
    new_rev = []
    for word in review:
        if word.pos_ in ['NOUN', 'ADJ', 'VERB', 'ADV']:
            new_rev.append(word)
    final_data.append(new_rev)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 100%|██████████| 239031/239031 [50:57<00:00, 78.18it/s]

# %%
data = [[str(token) for token in tokens] for tokens in tqdm(final_data)]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 100%|██████████| 239031/239031 [00:05<00:00, 42122.91it/s]

# %%
df = pd.DataFrame(
    {'tokens': data,
     'sentiment': df['sentiment']
    })
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.to_csv('/content/drive/MyDrive/NLP/Handin/Data/topic_modeling_final.csv', index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# data = df['tokens'].apply(ast.literal_eval)
# data = data.tolist()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-550f78091c85> in <cell line: 2>()
#       1 # data = df['tokens'].apply(ast.literal_eval)
# ----> 2 data = data.tolist()
#
# AttributeError: 'list' object has no attribute 'tolist'

# %%
data[:2]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['everyth',
#   'perfect',
#   'nice',
#   'clean',
#   'everyth_perfect',
#   'everyth_perfect_nice'],
#  ['appart',
#   'beautiful',
#   'veri',
#   'help',
#   'want',
#   'friendli_help',
#   'help_us',
#   'us_want',
#   'veri_friendli_help',
#   'friendli_help_us']]

# %% [markdown]
# ### Предварительная обработка данных

# %% [markdown]
# ##### Создаем словарь со всеми уникальными словами

# %%
id2word = corpora.Dictionary(data)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
corpus = []
for text in data:
    new = id2word.doc2bow(text)
    corpus.append(new)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(corpus[0])
# Out:
# [(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1)]
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
len(corpus)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 239031

# %%
corpus = [x for x in corpus if x]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
len(corpus)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 238530

# %% [markdown]
# ##### Фильтр для экстремальных значений

# %% [markdown]
# Токены, которые появляются в менее чем 30 отзывах или в более чем 80% отзывов будут отфильтрованы.
# Далее сохраняем 10 000 наиболее частых токенов.

# %%
id2word.filter_extremes(no_below=30, no_above=0.8, keep_n=10000)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(len(id2word.iteritems()))
# Out:
# 10000
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ##### Bag of words

# %%
bow_corpus = [id2word.doc2bow(doc) for doc in data]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(bow_corpus[0])
# Out:
# [(0, 1), (1, 1), (2, 1), (3, 1), (4, 1)]
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(len(bow_corpus))
# Out:
# 239031
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
first_review = bow_corpus[0]
for token in range(len(first_review)):
    print('Word {} (\"{}\") appears {} time.'.format(first_review[token][0], id2word[first_review[token][0]], first_review[token][1]))
# Out:
# Word 0 ("clean") appears 1 time.
# Word 1 ("everyth") appears 1 time.
# Word 2 ("everyth_perfect") appears 1 time.
# Word 3 ("nice") appears 1 time.
# Word 4 ("perfect") appears 1 time.
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Применяем TF-IDF

# %%
tfidf_model = TfidfModel(bow_corpus)
corpus_tfidf = tfidf_model[bow_corpus]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Запуск LDA с TF-IDF

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus_tfidf,
                                            id2word=id2word,
                                            num_topics=6,
                                            random_state=42,
                                            passes=5,
                                            alpha='auto')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Визуализация тем

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, bow_corpus, id2word, mds='mmds', R=15)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
vis
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 3     -0.160985  0.061601       1        1  70.433458
# 2     -0.257502  0.343440       2        1  14.607018
# 1      0.117366 -0.407160       3        1   4.843968
# 5      0.251462  0.337394       4        1   3.546629
# 0      0.403934 -0.072903       5        1   3.410802
# 4     -0.354276 -0.262372       6        1   3.158125, topic_info=              Term          Freq         Total Category  logprob  loglift
# 618    great_place   9828.000000   9828.000000  Default  15.0000  15.0000
# 504     place_stay  10040.000000  10040.000000  Default  14.0000  14.0000
# 620    place_great   6302.000000   6302.000000  Default  13.0000  13.0000
# 77           close  18284.000000  18284.000000  Default  12.0000  12.0000
# 3568   great_apart   4429.000000   4429.000000  Default  11.0000  11.0000
# ...            ...           ...           ...      ...      ...      ...
# 1841     back_soon    835.140925    839.714495   Topic6  -5.3614   3.4497
# 2608       appreci    826.622480    831.199735   Topic6  -5.3717   3.4497
# 5457            th    816.025332    820.601662   Topic6  -5.3846   3.4496
# 4010  apart_famili    816.053252    820.644762   Topic6  -5.3846   3.4496
# 1399     like_stay   1046.533688   1052.692395   Topic6  -5.1358   3.4493
#
# [154 rows x 6 columns], token_table=      Topic      Freq           Term
# term
# 5640      1  0.000761     amaz_apart
# 5640      2  0.000761     amaz_apart
# 5640      3  0.000761     amaz_apart
# 5640      4  0.000761     amaz_apart
# 5640      5  0.996634     amaz_apart
# ...     ...       ...            ...
# 2271      2  0.898641  would_definit
# 2271      3  0.000354  would_definit
# 2271      4  0.000354  would_definit
# 2271      5  0.000354  would_definit
# 2271      6  0.000354  would_definit
#
# [822 rows x 3 columns], R=15, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[4, 3, 2, 6, 1, 5])

# %%
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx+1, topic))
# Out:
# Topic: 1
# Words: 0.010*"locat_clean" + 0.009*"veri_nice_apart" + 0.008*"nice_room" + 0.007*"amaz_apart" + 0.007*"check_process" + 0.006*"host_nice" + 0.006*"room_nice" + 0.005*"requir" + 0.005*"veri_flexibl" + 0.005*"pillow"
# Topic: 2
# Words: 0.036*"great_place" + 0.032*"place_stay" + 0.021*"place_great" + 0.013*"nice_place" + 0.012*"bakeri" + 0.011*"spaciou_apart" + 0.010*"great_place_stay" + 0.010*"stay_great" + 0.008*"veri_nice_place" + 0.008*"apart_love"
# Topic: 3
# Words: 0.008*"close" + 0.006*"central" + 0.005*"friendli_host" + 0.005*"definit" + 0.005*"definit_recommend" + 0.004*"flat" + 0.004*"heart" + 0.004*"everyth_perfect" + 0.004*"nice" + 0.004*"metro"
# Topic: 4
# Words: 0.010*"great" + 0.009*"apart" + 0.008*"place" + 0.007*"stay" + 0.007*"nice" + 0.006*"host" + 0.005*"recommend" + 0.005*"good" + 0.005*"perfect" + 0.005*"clean"
# Topic: 5
# Words: 0.007*"groceri_store" + 0.006*"son" + 0.006*"great_area" + 0.006*"like_stay" + 0.006*"veri_good" + 0.005*"wash_machin" + 0.005*"beauti_view" + 0.005*"amaz_view" + 0.005*"apart_fantast" + 0.005*"miss"
# Topic: 6
# Words: 0.022*"great_apart" + 0.006*"pleas" + 0.006*"hostess" + 0.005*"great_apart_great" + 0.005*"nice_person" + 0.005*"stay_good" + 0.005*"practic" + 0.005*"convers" + 0.004*"oktoberfest" + 0.004*"locat_well"
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Запуск LDA без TF-IDF

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=bow_corpus,
                                            id2word=id2word,
                                            num_topics=6,
                                            random_state=42,
                                            passes=5,
                                            alpha='auto')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Визуализация тем

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, bow_corpus, id2word, mds='mmds', R=15)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/sklearn/manifold/_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
vis
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0      0.095356  0.318111       1        1  27.016635
# 4     -0.138650 -0.303911       2        1  22.806357
# 3     -0.391533 -0.071854       3        1  18.755928
# 2     -0.261628  0.315567       4        1  14.752484
# 1      0.279907 -0.353399       5        1  10.113472
# 5      0.416547  0.095486       6        1   6.555124, topic_info=          Term           Freq          Total Category  logprob  loglift
# 38       great  122813.000000  122813.000000  Default  15.0000  15.0000
# 66       place   92539.000000   92539.000000  Default  14.0000  14.0000
# 45        stay  139846.000000  139846.000000  Default  13.0000  13.0000
# 3         nice   49171.000000   49171.000000  Default  12.0000  12.0000
# 26   recommend   63280.000000   63280.000000  Default  11.0000  11.0000
# ..         ...            ...            ...      ...      ...      ...
# 958  dure_stay    3292.842713    3999.038786   Topic6  -4.7198   2.5306
# 511       dure    5108.472449    9367.757340   Topic6  -4.2807   2.1185
# 19          go    6621.595360   17510.624443   Topic6  -4.0212   1.7525
# 717      local    4352.421025    8729.237804   Topic6  -4.4408   2.0290
# 8         help    4070.296546   35968.036391   Topic6  -4.5078   0.5460
#
# [184 rows x 6 columns], token_table=      Topic      Freq                Term
# term
# 340       3  0.001609              access
# 340       4  0.998302              access
# 122       1  0.006901                also
# 122       2  0.381884                also
# 122       3  0.435037                also
# ...     ...       ...                 ...
# 415       2  0.990072                work
# 415       3  0.008583                work
# 415       4  0.001297                work
# 456       1  0.999789  would_definit_stay
# 244       1  0.999594     would_recommend
#
# [319 rows x 3 columns], R=15, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 5, 4, 3, 2, 6])

# %%
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx+1, topic))
# Out:
# Topic: 1
# Words: 0.089*"stay" + 0.045*"host" + 0.042*"recommend" + 0.025*"apart" + 0.024*"love" + 0.024*"perfect" + 0.021*"help" + 0.017*"wonder" + 0.017*"veri" + 0.016*"hous"
# Topic: 2
# Words: 0.216*"great" + 0.162*"place" + 0.026*"back" + 0.022*"come" + 0.021*"place_stay" + 0.019*"thi_place" + 0.016*"great_place" + 0.015*"great_stay" + 0.015*"great_locat" + 0.015*"come_back"
# Topic: 3
# Words: 0.059*"nice" + 0.048*"apart" + 0.040*"good" + 0.035*"close" + 0.026*"easi" + 0.022*"clean" + 0.021*"quiet" + 0.021*"flat" + 0.016*"veri_nice" + 0.014*"veri"
# Topic: 4
# Words: 0.035*"walk" + 0.022*"restaur" + 0.019*"station" + 0.016*"lot" + 0.015*"space" + 0.015*"room" + 0.014*"area" + 0.014*"train" + 0.014*"apart" + 0.011*"also"
# Topic: 5
# Words: 0.018*"make" + 0.018*"thi" + 0.014*"even" + 0.013*"day" + 0.012*"time" + 0.011*"get" + 0.010*"night" + 0.010*"room" + 0.009*"feel" + 0.009*"best"
# Topic: 6
# Words: 0.034*"give" + 0.026*"question" + 0.025*"trip" + 0.021*"quick" + 0.020*"alway" + 0.018*"ani" + 0.018*"go" + 0.016*"return" + 0.014*"dure" + 0.014*"give_us"
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
